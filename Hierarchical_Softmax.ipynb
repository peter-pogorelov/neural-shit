# %%
# CLone my repo that contains the shell file
# !git clone https://gist.github.com/f7b7c7758a46da49f84bc68b47997d69.git
# !cd f7b7c7758a46da49f84bc68b47997d69/
# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod2/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.148-1_amd64
# !dpkg --install cuda-repo-ubuntu1604-9-2-local_9.2.148-1_amd64
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda
# Check the version of CUDA on the system
# !cat /usr/local/cuda/version.txt
# !pip install http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# !pip install torchvision

# %%
import torch

print("PyTorch version: ")
print(torch.__version__)
print("CUDA Version: ")
print(torch.version.cuda)
print("cuDNN version is: ")
print(torch.backends.cudnn.version())
# Out:
# PyTorch version:
# 1.4.0
# CUDA Version:
# 10.1
# cuDNN version is:
# 7603

# %%
from sklearn.datasets import make_classification
from sortedcontainers import SortedList
import numpy as np

# %%
X, y = make_classification(n_samples=2000, n_features=20, n_informative=10, n_classes=10, weights = np.arange(10) / np.sum(np.arange(10)))

# %%
X_train = X[:-100, :]
y_train = y[:-100]

X_test = X[-100:, :]
y_test = y[-100:]

# %%
class HierarchicalSoftmaxNetwork(torch.nn.Module):
  def __init__(self, input_size, hidden_size, target_distr: dict):
    super().__init__()
    self.hidden_size = hidden_size
    self.layers = list()
    self.build_huffman_tree(target_distr)
    self.sigmoid = torch.nn.Sigmoid()
    self.tanh = torch.nn.ReLU()
    self.linear = torch.nn.Linear(input_size, hidden_size, True).type(torch.float32)

  def make_node(self, name, value) -> dict:
    linear = torch.nn.Linear(self.hidden_size, 1, True).type(torch.float32)
    self.add_module(f'{name}', linear)
    return {
        'name': name,
        'value': value,
        'left': None,
        'right': None,
        'neuron': linear
    }

  def build_huffman_tree(self, target_distr: dict):
    self.nodes = [self.make_node([k], v) for k, v in target_distr.items()]
    self.flist = SortedList(self.nodes, key=lambda x: -x['value'])

    while len(self.flist) != 1:
      a = self.flist.pop()
      b = self.flist.pop()
      r = self.make_node(a['name']+b['name'], a['value']+b['value'])
      r['left'] = a
      r['right'] = b
      self.flist.add(r)


  def decode(self, key) -> tuple:
    path = list()
    neurons = list()
    node = self.flist[0]
    
    while True:
      if node['left'] and key in node['left']['name']:
        neurons.append(node['neuron'])
        path.append(0)
        node = node['left']
      elif node['right'] and key in node['right']['name']:
        neurons.append(node['neuron'])
        path.append(1)
        node = node['right']
      else:
        break
            
    return path, neurons


  def hsoftmax(self, hidden_state: torch.Tensor):
    result = list()
    node = self.flist[0]

    while True:
      pred = self.sigmoid(node['neuron'](hidden_state))

      #p = pred.detach().numpy()
      if pred < 0.5:
        node = node['left']
      else:
        node = node['right']

      result.append(pred)

      if node['left'] is None and node['right'] is None:
        break

    return result

  def hsoftmax_train(self, hidden_state: torch.Tensor, target: list):
    result = list()
    node = self.flist[0]

    for i in target:
      pred = self.sigmoid(node['neuron'](hidden_state))

      if i == 0:
        node = node['left']
      elif i == 1:
        node = node['right']

      result.append(pred)

    return result

  def forward(self, x):
    line = self.tanh(self.linear(x))
    return self.hsoftmax(line)
  
  def forward_train(self, x, target: list):
    line = self.tanh(self.linear(x))
    return self.hsoftmax_train(line, target)

# %%
class HierarchicalSoftmaxLoss(torch.nn.Module):
  def __init__(self):
    super().__init__()
    
  def forward(self, _input: list, _target: list):
    result = torch.Tensor([0]).type(torch.float32)
    for p, y in zip(_input, _target):
      result += y * torch.log(p + 1e-9) + (1-y)*torch.log(1-p+1e-9)
      #if y == 1 and p < 0.5 or y == 0 and p >= 0.5:
      #  break
      

    return -result.sum() # :C

# %%
y_u, y_c = np.unique(y, return_counts=True)

hsf = HierarchicalSoftmaxNetwork(20, 20, dict(zip(y_u, y_c)))

optimizer = torch.optim.Adam(hsf.parameters(), lr = 0.1)
criterion = HierarchicalSoftmaxLoss()

# %%
X_torch = torch.from_numpy(X_train).type(torch.float32)
X_torch.requires_grad = False

# %%
y_tensors = dict()
y_numpies = dict()

for i in y_u:
  y_np, _ = hsf.decode(i)
  y_tensors[i] = torch.from_numpy(np.array(y_np)).type(torch.float32)
  y_numpies[i] = y_np
y_tensors
# Out:
# {0: tensor([1., 0., 1., 1., 0., 0.]),
#  1: tensor([1., 0., 1., 1., 0., 1.]),
#  2: tensor([1., 0., 1., 1., 1.]),
#  3: tensor([1., 0., 1., 0.]),
#  4: tensor([0., 0., 0.]),
#  5: tensor([0., 0., 1.]),
#  6: tensor([1., 0., 0.]),
#  7: tensor([1., 1., 0.]),
#  8: tensor([1., 1., 1.]),
#  9: tensor([0., 1.])}

# %%
hsf.train()
for epoch in range(100):
  optimizer.zero_grad()
  losses = list()
  for i in range(X_train.shape[0]):    
    X_torch.requires_grad = False
    y_tensors[y_train[i]].requires_grad = False

    output = hsf.forward_train(X_torch[i, :], y_numpies[y_train[i]])
    if i % 100 == 0:
      print(output, y_tensors[y_train[i]])
    losses.append(criterion(output, y_tensors[y_train[i]]))#, y_sub)

  result = torch.Tensor([0]).type(torch.float32)
  for l in losses:
    result += l
  result = result.mean()
  result.backward()

  #loss.backward()
  optimizer.step()

  print('epoch {}, loss {}'.format(epoch,-np.sum(list(map(lambda x: x.data, losses)))))
# Out:
# [tensor([0.1723], grad_fn=<SigmoidBackward>), tensor([0.0783], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9131], grad_fn=<SigmoidBackward>), tensor([0.9342], grad_fn=<SigmoidBackward>), tensor([0.9920], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8462], grad_fn=<SigmoidBackward>), tensor([0.6039], grad_fn=<SigmoidBackward>), tensor([0.9973], grad_fn=<SigmoidBackward>), tensor([0.0212], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8811], grad_fn=<SigmoidBackward>), tensor([0.2286], grad_fn=<SigmoidBackward>), tensor([0.6682], grad_fn=<SigmoidBackward>), tensor([0.0100], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2619], grad_fn=<SigmoidBackward>), tensor([0.3161], grad_fn=<SigmoidBackward>), tensor([0.9939], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7224], grad_fn=<SigmoidBackward>), tensor([0.3157], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9283], grad_fn=<SigmoidBackward>), tensor([0.9953], grad_fn=<SigmoidBackward>), tensor([0.0007], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9876], grad_fn=<SigmoidBackward>), tensor([0.9867], grad_fn=<SigmoidBackward>), tensor([8.0336e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9005], grad_fn=<SigmoidBackward>), tensor([0.0292], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([1.7669e-14], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3687], grad_fn=<SigmoidBackward>), tensor([0.0689], grad_fn=<SigmoidBackward>), tensor([0.4820], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1747], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3502], grad_fn=<SigmoidBackward>), tensor([0.0131], grad_fn=<SigmoidBackward>), tensor([0.9329], grad_fn=<SigmoidBackward>), tensor([0.0274], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8084], grad_fn=<SigmoidBackward>), tensor([0.0077], grad_fn=<SigmoidBackward>), tensor([0.0007], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9370], grad_fn=<SigmoidBackward>), tensor([0.0349], grad_fn=<SigmoidBackward>), tensor([0.5761], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9143], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2130], grad_fn=<SigmoidBackward>), tensor([0.2902], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9029], grad_fn=<SigmoidBackward>), tensor([0.9291], grad_fn=<SigmoidBackward>), tensor([0.1843], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.3957], grad_fn=<SigmoidBackward>), tensor([0.9469], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9081], grad_fn=<SigmoidBackward>), tensor([0.0505], grad_fn=<SigmoidBackward>), tensor([1.2177e-13], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8156], grad_fn=<SigmoidBackward>), tensor([0.0416], grad_fn=<SigmoidBackward>), tensor([0.9984], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 0, loss -1478.293212890625
# [tensor([0.1794], grad_fn=<SigmoidBackward>), tensor([0.0784], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9144], grad_fn=<SigmoidBackward>), tensor([0.9247], grad_fn=<SigmoidBackward>), tensor([0.9935], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8496], grad_fn=<SigmoidBackward>), tensor([0.5844], grad_fn=<SigmoidBackward>), tensor([0.9970], grad_fn=<SigmoidBackward>), tensor([0.0179], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8844], grad_fn=<SigmoidBackward>), tensor([0.2099], grad_fn=<SigmoidBackward>), tensor([0.6357], grad_fn=<SigmoidBackward>), tensor([0.0096], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2613], grad_fn=<SigmoidBackward>), tensor([0.3246], grad_fn=<SigmoidBackward>), tensor([0.9954], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7399], grad_fn=<SigmoidBackward>), tensor([0.3168], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9398], grad_fn=<SigmoidBackward>), tensor([0.9931], grad_fn=<SigmoidBackward>), tensor([0.0013], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9898], grad_fn=<SigmoidBackward>), tensor([0.9797], grad_fn=<SigmoidBackward>), tensor([0.0002], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9064], grad_fn=<SigmoidBackward>), tensor([0.0240], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([1.2478e-14], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3710], grad_fn=<SigmoidBackward>), tensor([0.0680], grad_fn=<SigmoidBackward>), tensor([0.4878], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1789], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3551], grad_fn=<SigmoidBackward>), tensor([0.0111], grad_fn=<SigmoidBackward>), tensor([0.9120], grad_fn=<SigmoidBackward>), tensor([0.0259], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8138], grad_fn=<SigmoidBackward>), tensor([0.0067], grad_fn=<SigmoidBackward>), tensor([0.0005], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9399], grad_fn=<SigmoidBackward>), tensor([0.0279], grad_fn=<SigmoidBackward>), tensor([0.4664], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9294], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2182], grad_fn=<SigmoidBackward>), tensor([0.3068], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9029], grad_fn=<SigmoidBackward>), tensor([0.9219], grad_fn=<SigmoidBackward>), tensor([0.1982], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4070], grad_fn=<SigmoidBackward>), tensor([0.9506], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9123], grad_fn=<SigmoidBackward>), tensor([0.0470], grad_fn=<SigmoidBackward>), tensor([6.8351e-14], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8184], grad_fn=<SigmoidBackward>), tensor([0.0419], grad_fn=<SigmoidBackward>), tensor([0.9988], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 1, loss -1475.546875
# [tensor([0.1915], grad_fn=<SigmoidBackward>), tensor([0.0797], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9152], grad_fn=<SigmoidBackward>), tensor([0.9271], grad_fn=<SigmoidBackward>), tensor([0.9933], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8525], grad_fn=<SigmoidBackward>), tensor([0.5994], grad_fn=<SigmoidBackward>), tensor([0.9973], grad_fn=<SigmoidBackward>), tensor([0.0164], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8870], grad_fn=<SigmoidBackward>), tensor([0.2241], grad_fn=<SigmoidBackward>), tensor([0.6524], grad_fn=<SigmoidBackward>), tensor([0.0091], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2683], grad_fn=<SigmoidBackward>), tensor([0.3100], grad_fn=<SigmoidBackward>), tensor([0.9960], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7613], grad_fn=<SigmoidBackward>), tensor([0.3124], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9431], grad_fn=<SigmoidBackward>), tensor([0.9951], grad_fn=<SigmoidBackward>), tensor([0.0010], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9908], grad_fn=<SigmoidBackward>), tensor([0.9857], grad_fn=<SigmoidBackward>), tensor([0.0001], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9132], grad_fn=<SigmoidBackward>), tensor([0.0260], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([1.2330e-14], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3797], grad_fn=<SigmoidBackward>), tensor([0.0767], grad_fn=<SigmoidBackward>), tensor([0.4835], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1882], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3625], grad_fn=<SigmoidBackward>), tensor([0.0120], grad_fn=<SigmoidBackward>), tensor([0.9275], grad_fn=<SigmoidBackward>), tensor([0.0206], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8173], grad_fn=<SigmoidBackward>), tensor([0.0064], grad_fn=<SigmoidBackward>), tensor([0.0004], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9431], grad_fn=<SigmoidBackward>), tensor([0.0315], grad_fn=<SigmoidBackward>), tensor([0.5410], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9304], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2289], grad_fn=<SigmoidBackward>), tensor([0.2822], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9036], grad_fn=<SigmoidBackward>), tensor([0.9243], grad_fn=<SigmoidBackward>), tensor([0.1862], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4255], grad_fn=<SigmoidBackward>), tensor([0.9345], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9168], grad_fn=<SigmoidBackward>), tensor([0.0478], grad_fn=<SigmoidBackward>), tensor([4.1595e-14], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8205], grad_fn=<SigmoidBackward>), tensor([0.0478], grad_fn=<SigmoidBackward>), tensor([0.9989], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 2, loss -1474.297119140625
# [tensor([0.1712], grad_fn=<SigmoidBackward>), tensor([0.0888], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9114], grad_fn=<SigmoidBackward>), tensor([0.9234], grad_fn=<SigmoidBackward>), tensor([0.9928], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8484], grad_fn=<SigmoidBackward>), tensor([0.5971], grad_fn=<SigmoidBackward>), tensor([0.9976], grad_fn=<SigmoidBackward>), tensor([0.0161], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8801], grad_fn=<SigmoidBackward>), tensor([0.2195], grad_fn=<SigmoidBackward>), tensor([0.6498], grad_fn=<SigmoidBackward>), tensor([0.0096], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2561], grad_fn=<SigmoidBackward>), tensor([0.3261], grad_fn=<SigmoidBackward>), tensor([0.9962], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7365], grad_fn=<SigmoidBackward>), tensor([0.3165], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9255], grad_fn=<SigmoidBackward>), tensor([0.9947], grad_fn=<SigmoidBackward>), tensor([0.0008], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9874], grad_fn=<SigmoidBackward>), tensor([0.9844], grad_fn=<SigmoidBackward>), tensor([8.7472e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9029], grad_fn=<SigmoidBackward>), tensor([0.0234], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([1.4540e-14], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3700], grad_fn=<SigmoidBackward>), tensor([0.0805], grad_fn=<SigmoidBackward>), tensor([0.4586], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1748], grad_fn=<SigmoidBackward>), tensor([0.9994], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3361], grad_fn=<SigmoidBackward>), tensor([0.0108], grad_fn=<SigmoidBackward>), tensor([0.9301], grad_fn=<SigmoidBackward>), tensor([0.0200], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.7925], grad_fn=<SigmoidBackward>), tensor([0.0059], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9352], grad_fn=<SigmoidBackward>), tensor([0.0296], grad_fn=<SigmoidBackward>), tensor([0.5280], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9424], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2235], grad_fn=<SigmoidBackward>), tensor([0.2952], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8973], grad_fn=<SigmoidBackward>), tensor([0.9213], grad_fn=<SigmoidBackward>), tensor([0.1779], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4141], grad_fn=<SigmoidBackward>), tensor([0.9282], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9040], grad_fn=<SigmoidBackward>), tensor([0.0485], grad_fn=<SigmoidBackward>), tensor([2.6218e-14], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8119], grad_fn=<SigmoidBackward>), tensor([0.0423], grad_fn=<SigmoidBackward>), tensor([0.9992], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 3, loss -1473.66064453125
# [tensor([0.1925], grad_fn=<SigmoidBackward>), tensor([0.0914], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9235], grad_fn=<SigmoidBackward>), tensor([0.9220], grad_fn=<SigmoidBackward>), tensor([0.9936], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8582], grad_fn=<SigmoidBackward>), tensor([0.6021], grad_fn=<SigmoidBackward>), tensor([0.9979], grad_fn=<SigmoidBackward>), tensor([0.0146], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8899], grad_fn=<SigmoidBackward>), tensor([0.2211], grad_fn=<SigmoidBackward>), tensor([0.6644], grad_fn=<SigmoidBackward>), tensor([0.0089], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2726], grad_fn=<SigmoidBackward>), tensor([0.3386], grad_fn=<SigmoidBackward>), tensor([0.9965], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7623], grad_fn=<SigmoidBackward>), tensor([0.3235], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9460], grad_fn=<SigmoidBackward>), tensor([0.9945], grad_fn=<SigmoidBackward>), tensor([0.0012], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9920], grad_fn=<SigmoidBackward>), tensor([0.9839], grad_fn=<SigmoidBackward>), tensor([0.0001], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9214], grad_fn=<SigmoidBackward>), tensor([0.0232], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([9.9137e-15], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4034], grad_fn=<SigmoidBackward>), tensor([0.0840], grad_fn=<SigmoidBackward>), tensor([0.4576], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1896], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3564], grad_fn=<SigmoidBackward>), tensor([0.0104], grad_fn=<SigmoidBackward>), tensor([0.9390], grad_fn=<SigmoidBackward>), tensor([0.0236], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8220], grad_fn=<SigmoidBackward>), tensor([0.0064], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9447], grad_fn=<SigmoidBackward>), tensor([0.0293], grad_fn=<SigmoidBackward>), tensor([0.5385], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9533], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2401], grad_fn=<SigmoidBackward>), tensor([0.2918], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9029], grad_fn=<SigmoidBackward>), tensor([0.9200], grad_fn=<SigmoidBackward>), tensor([0.1854], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4379], grad_fn=<SigmoidBackward>), tensor([0.9295], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9192], grad_fn=<SigmoidBackward>), tensor([0.0518], grad_fn=<SigmoidBackward>), tensor([1.7739e-14], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8369], grad_fn=<SigmoidBackward>), tensor([0.0456], grad_fn=<SigmoidBackward>), tensor([0.9993], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 4, loss -1473.488525390625
# [tensor([0.1594], grad_fn=<SigmoidBackward>), tensor([0.0788], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9118], grad_fn=<SigmoidBackward>), tensor([0.9274], grad_fn=<SigmoidBackward>), tensor([0.9926], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8546], grad_fn=<SigmoidBackward>), tensor([0.6234], grad_fn=<SigmoidBackward>), tensor([0.9982], grad_fn=<SigmoidBackward>), tensor([0.0135], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8790], grad_fn=<SigmoidBackward>), tensor([0.2410], grad_fn=<SigmoidBackward>), tensor([0.6729], grad_fn=<SigmoidBackward>), tensor([0.0083], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2580], grad_fn=<SigmoidBackward>), tensor([0.3236], grad_fn=<SigmoidBackward>), tensor([0.9960], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7169], grad_fn=<SigmoidBackward>), tensor([0.3112], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9212], grad_fn=<SigmoidBackward>), tensor([0.9961], grad_fn=<SigmoidBackward>), tensor([0.0007], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9866], grad_fn=<SigmoidBackward>), tensor([0.9885], grad_fn=<SigmoidBackward>), tensor([7.4905e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.8975], grad_fn=<SigmoidBackward>), tensor([0.0268], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([4.9526e-15], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3875], grad_fn=<SigmoidBackward>), tensor([0.0820], grad_fn=<SigmoidBackward>), tensor([0.4988], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1623], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3090], grad_fn=<SigmoidBackward>), tensor([0.0107], grad_fn=<SigmoidBackward>), tensor([0.9422], grad_fn=<SigmoidBackward>), tensor([0.0340], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.7923], grad_fn=<SigmoidBackward>), tensor([0.0057], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9329], grad_fn=<SigmoidBackward>), tensor([0.0329], grad_fn=<SigmoidBackward>), tensor([0.5253], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9566], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2307], grad_fn=<SigmoidBackward>), tensor([0.2623], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8947], grad_fn=<SigmoidBackward>), tensor([0.9228], grad_fn=<SigmoidBackward>), tensor([0.1668], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4166], grad_fn=<SigmoidBackward>), tensor([0.9205], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9046], grad_fn=<SigmoidBackward>), tensor([0.0465], grad_fn=<SigmoidBackward>), tensor([1.0672e-14], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8136], grad_fn=<SigmoidBackward>), tensor([0.0479], grad_fn=<SigmoidBackward>), tensor([0.9993], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 5, loss -1473.046875
# [tensor([0.1926], grad_fn=<SigmoidBackward>), tensor([0.0894], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9233], grad_fn=<SigmoidBackward>), tensor([0.9155], grad_fn=<SigmoidBackward>), tensor([0.9938], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8695], grad_fn=<SigmoidBackward>), tensor([0.6104], grad_fn=<SigmoidBackward>), tensor([0.9982], grad_fn=<SigmoidBackward>), tensor([0.0111], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8936], grad_fn=<SigmoidBackward>), tensor([0.2230], grad_fn=<SigmoidBackward>), tensor([0.6738], grad_fn=<SigmoidBackward>), tensor([0.0067], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2795], grad_fn=<SigmoidBackward>), tensor([0.3563], grad_fn=<SigmoidBackward>), tensor([0.9954], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7612], grad_fn=<SigmoidBackward>), tensor([0.3374], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9527], grad_fn=<SigmoidBackward>), tensor([0.9938], grad_fn=<SigmoidBackward>), tensor([0.0011], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9931], grad_fn=<SigmoidBackward>), tensor([0.9812], grad_fn=<SigmoidBackward>), tensor([0.0001], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9184], grad_fn=<SigmoidBackward>), tensor([0.0217], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([2.8193e-15], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4172], grad_fn=<SigmoidBackward>), tensor([0.0731], grad_fn=<SigmoidBackward>), tensor([0.5446], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1884], grad_fn=<SigmoidBackward>), tensor([0.9994], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3514], grad_fn=<SigmoidBackward>), tensor([0.0089], grad_fn=<SigmoidBackward>), tensor([0.9387], grad_fn=<SigmoidBackward>), tensor([0.0354], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8353], grad_fn=<SigmoidBackward>), tensor([0.0056], grad_fn=<SigmoidBackward>), tensor([0.0004], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9475], grad_fn=<SigmoidBackward>), tensor([0.0267], grad_fn=<SigmoidBackward>), tensor([0.4955], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9538], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2511], grad_fn=<SigmoidBackward>), tensor([0.3216], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9022], grad_fn=<SigmoidBackward>), tensor([0.9173], grad_fn=<SigmoidBackward>), tensor([0.1649], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4500], grad_fn=<SigmoidBackward>), tensor([0.9444], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9273], grad_fn=<SigmoidBackward>), tensor([0.0464], grad_fn=<SigmoidBackward>), tensor([6.7335e-15], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8357], grad_fn=<SigmoidBackward>), tensor([0.0470], grad_fn=<SigmoidBackward>), tensor([0.9994], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 6, loss -1473.52197265625
# [tensor([0.1477], grad_fn=<SigmoidBackward>), tensor([0.0786], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9082], grad_fn=<SigmoidBackward>), tensor([0.9252], grad_fn=<SigmoidBackward>), tensor([0.9933], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8606], grad_fn=<SigmoidBackward>), tensor([0.6314], grad_fn=<SigmoidBackward>), tensor([0.9981], grad_fn=<SigmoidBackward>), tensor([0.0116], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8790], grad_fn=<SigmoidBackward>), tensor([0.2480], grad_fn=<SigmoidBackward>), tensor([0.6711], grad_fn=<SigmoidBackward>), tensor([0.0085], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2530], grad_fn=<SigmoidBackward>), tensor([0.3298], grad_fn=<SigmoidBackward>), tensor([0.9954], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7057], grad_fn=<SigmoidBackward>), tensor([0.3202], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9222], grad_fn=<SigmoidBackward>), tensor([0.9965], grad_fn=<SigmoidBackward>), tensor([0.0007], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9862], grad_fn=<SigmoidBackward>), tensor([0.9899], grad_fn=<SigmoidBackward>), tensor([7.5543e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.8875], grad_fn=<SigmoidBackward>), tensor([0.0269], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([2.4904e-15], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3746], grad_fn=<SigmoidBackward>), tensor([0.0783], grad_fn=<SigmoidBackward>), tensor([0.5581], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1622], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3082], grad_fn=<SigmoidBackward>), tensor([0.0103], grad_fn=<SigmoidBackward>), tensor([0.9418], grad_fn=<SigmoidBackward>), tensor([0.0363], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.7911], grad_fn=<SigmoidBackward>), tensor([0.0063], grad_fn=<SigmoidBackward>), tensor([0.0004], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9312], grad_fn=<SigmoidBackward>), tensor([0.0345], grad_fn=<SigmoidBackward>), tensor([0.5402], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9491], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2335], grad_fn=<SigmoidBackward>), tensor([0.2554], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8886], grad_fn=<SigmoidBackward>), tensor([0.9257], grad_fn=<SigmoidBackward>), tensor([0.1485], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4222], grad_fn=<SigmoidBackward>), tensor([0.9244], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9046], grad_fn=<SigmoidBackward>), tensor([0.0472], grad_fn=<SigmoidBackward>), tensor([3.9161e-15], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8027], grad_fn=<SigmoidBackward>), tensor([0.0640], grad_fn=<SigmoidBackward>), tensor([0.9993], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 7, loss -1474.6446533203125
# [tensor([0.1883], grad_fn=<SigmoidBackward>), tensor([0.1011], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9271], grad_fn=<SigmoidBackward>), tensor([0.9115], grad_fn=<SigmoidBackward>), tensor([0.9943], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8740], grad_fn=<SigmoidBackward>), tensor([0.6047], grad_fn=<SigmoidBackward>), tensor([0.9979], grad_fn=<SigmoidBackward>), tensor([0.0090], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8956], grad_fn=<SigmoidBackward>), tensor([0.2226], grad_fn=<SigmoidBackward>), tensor([0.6569], grad_fn=<SigmoidBackward>), tensor([0.0069], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2729], grad_fn=<SigmoidBackward>), tensor([0.3670], grad_fn=<SigmoidBackward>), tensor([0.9957], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7591], grad_fn=<SigmoidBackward>), tensor([0.3172], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9546], grad_fn=<SigmoidBackward>), tensor([0.9940], grad_fn=<SigmoidBackward>), tensor([0.0014], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9937], grad_fn=<SigmoidBackward>), tensor([0.9818], grad_fn=<SigmoidBackward>), tensor([0.0001], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9224], grad_fn=<SigmoidBackward>), tensor([0.0194], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([2.1461e-15], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4144], grad_fn=<SigmoidBackward>), tensor([0.0702], grad_fn=<SigmoidBackward>), tensor([0.5503], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1993], grad_fn=<SigmoidBackward>), tensor([0.9993], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3686], grad_fn=<SigmoidBackward>), tensor([0.0080], grad_fn=<SigmoidBackward>), tensor([0.9375], grad_fn=<SigmoidBackward>), tensor([0.0208], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8337], grad_fn=<SigmoidBackward>), tensor([0.0055], grad_fn=<SigmoidBackward>), tensor([0.0006], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9471], grad_fn=<SigmoidBackward>), tensor([0.0266], grad_fn=<SigmoidBackward>), tensor([0.5316], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9563], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2523], grad_fn=<SigmoidBackward>), tensor([0.3199], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8957], grad_fn=<SigmoidBackward>), tensor([0.9197], grad_fn=<SigmoidBackward>), tensor([0.1419], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4596], grad_fn=<SigmoidBackward>), tensor([0.9390], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9268], grad_fn=<SigmoidBackward>), tensor([0.0470], grad_fn=<SigmoidBackward>), tensor([2.3245e-15], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8399], grad_fn=<SigmoidBackward>), tensor([0.0473], grad_fn=<SigmoidBackward>), tensor([0.9996], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 8, loss -1475.7615966796875
# [tensor([0.1428], grad_fn=<SigmoidBackward>), tensor([0.0949], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9087], grad_fn=<SigmoidBackward>), tensor([0.9274], grad_fn=<SigmoidBackward>), tensor([0.9928], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8599], grad_fn=<SigmoidBackward>), tensor([0.6327], grad_fn=<SigmoidBackward>), tensor([0.9982], grad_fn=<SigmoidBackward>), tensor([0.0105], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8754], grad_fn=<SigmoidBackward>), tensor([0.2545], grad_fn=<SigmoidBackward>), tensor([0.6867], grad_fn=<SigmoidBackward>), tensor([0.0104], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2427], grad_fn=<SigmoidBackward>), tensor([0.3517], grad_fn=<SigmoidBackward>), tensor([0.9960], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6937], grad_fn=<SigmoidBackward>), tensor([0.3203], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9055], grad_fn=<SigmoidBackward>), tensor([0.9972], grad_fn=<SigmoidBackward>), tensor([0.0005], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9832], grad_fn=<SigmoidBackward>), tensor([0.9914], grad_fn=<SigmoidBackward>), tensor([3.7094e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.8896], grad_fn=<SigmoidBackward>), tensor([0.0256], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([2.0986e-15], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3776], grad_fn=<SigmoidBackward>), tensor([0.0782], grad_fn=<SigmoidBackward>), tensor([0.5401], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1632], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3027], grad_fn=<SigmoidBackward>), tensor([0.0096], grad_fn=<SigmoidBackward>), tensor([0.9584], grad_fn=<SigmoidBackward>), tensor([0.0260], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.7768], grad_fn=<SigmoidBackward>), tensor([0.0063], grad_fn=<SigmoidBackward>), tensor([0.0006], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9246], grad_fn=<SigmoidBackward>), tensor([0.0348], grad_fn=<SigmoidBackward>), tensor([0.7028], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9448], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2336], grad_fn=<SigmoidBackward>), tensor([0.2564], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8792], grad_fn=<SigmoidBackward>), tensor([0.9284], grad_fn=<SigmoidBackward>), tensor([0.1158], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4379], grad_fn=<SigmoidBackward>), tensor([0.9140], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8991], grad_fn=<SigmoidBackward>), tensor([0.0528], grad_fn=<SigmoidBackward>), tensor([1.2739e-15], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8034], grad_fn=<SigmoidBackward>), tensor([0.0682], grad_fn=<SigmoidBackward>), tensor([0.9996], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 9, loss -1477.952880859375
# [tensor([0.2095], grad_fn=<SigmoidBackward>), tensor([0.0913], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9312], grad_fn=<SigmoidBackward>), tensor([0.9133], grad_fn=<SigmoidBackward>), tensor([0.9948], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8764], grad_fn=<SigmoidBackward>), tensor([0.5999], grad_fn=<SigmoidBackward>), tensor([0.9981], grad_fn=<SigmoidBackward>), tensor([0.0088], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8982], grad_fn=<SigmoidBackward>), tensor([0.2240], grad_fn=<SigmoidBackward>), tensor([0.6423], grad_fn=<SigmoidBackward>), tensor([0.0061], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2762], grad_fn=<SigmoidBackward>), tensor([0.3639], grad_fn=<SigmoidBackward>), tensor([0.9964], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7727], grad_fn=<SigmoidBackward>), tensor([0.2892], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9563], grad_fn=<SigmoidBackward>), tensor([0.9944], grad_fn=<SigmoidBackward>), tensor([0.0014], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9942], grad_fn=<SigmoidBackward>), tensor([0.9818], grad_fn=<SigmoidBackward>), tensor([0.0001], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9318], grad_fn=<SigmoidBackward>), tensor([0.0197], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([1.0590e-15], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4301], grad_fn=<SigmoidBackward>), tensor([0.0712], grad_fn=<SigmoidBackward>), tensor([0.5145], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.2066], grad_fn=<SigmoidBackward>), tensor([0.9993], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3715], grad_fn=<SigmoidBackward>), tensor([0.0075], grad_fn=<SigmoidBackward>), tensor([0.9275], grad_fn=<SigmoidBackward>), tensor([0.0183], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8391], grad_fn=<SigmoidBackward>), tensor([0.0045], grad_fn=<SigmoidBackward>), tensor([0.0009], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9481], grad_fn=<SigmoidBackward>), tensor([0.0245], grad_fn=<SigmoidBackward>), tensor([0.4702], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9561], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2672], grad_fn=<SigmoidBackward>), tensor([0.2914], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8935], grad_fn=<SigmoidBackward>), tensor([0.9198], grad_fn=<SigmoidBackward>), tensor([0.1302], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4916], grad_fn=<SigmoidBackward>), tensor([0.9293], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9344], grad_fn=<SigmoidBackward>), tensor([0.0447], grad_fn=<SigmoidBackward>), tensor([7.8772e-16], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8489], grad_fn=<SigmoidBackward>), tensor([0.0481], grad_fn=<SigmoidBackward>), tensor([0.9997], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 10, loss -1481.20458984375
# [tensor([0.1369], grad_fn=<SigmoidBackward>), tensor([0.0896], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9055], grad_fn=<SigmoidBackward>), tensor([0.9305], grad_fn=<SigmoidBackward>), tensor([0.9930], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8562], grad_fn=<SigmoidBackward>), tensor([0.6364], grad_fn=<SigmoidBackward>), tensor([0.9986], grad_fn=<SigmoidBackward>), tensor([0.0114], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8710], grad_fn=<SigmoidBackward>), tensor([0.2670], grad_fn=<SigmoidBackward>), tensor([0.7169], grad_fn=<SigmoidBackward>), tensor([0.0065], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2305], grad_fn=<SigmoidBackward>), tensor([0.3602], grad_fn=<SigmoidBackward>), tensor([0.9961], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6656], grad_fn=<SigmoidBackward>), tensor([0.3080], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8890], grad_fn=<SigmoidBackward>), tensor([0.9977], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9801], grad_fn=<SigmoidBackward>), tensor([0.9926], grad_fn=<SigmoidBackward>), tensor([3.4118e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.8784], grad_fn=<SigmoidBackward>), tensor([0.0307], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([8.0799e-16], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3654], grad_fn=<SigmoidBackward>), tensor([0.0754], grad_fn=<SigmoidBackward>), tensor([0.5757], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1484], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.2810], grad_fn=<SigmoidBackward>), tensor([0.0100], grad_fn=<SigmoidBackward>), tensor([0.9632], grad_fn=<SigmoidBackward>), tensor([0.0244], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.7495], grad_fn=<SigmoidBackward>), tensor([0.0049], grad_fn=<SigmoidBackward>), tensor([0.0006], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9185], grad_fn=<SigmoidBackward>), tensor([0.0349], grad_fn=<SigmoidBackward>), tensor([0.6991], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9546], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2326], grad_fn=<SigmoidBackward>), tensor([0.2520], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8752], grad_fn=<SigmoidBackward>), tensor([0.9315], grad_fn=<SigmoidBackward>), tensor([0.1026], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4441], grad_fn=<SigmoidBackward>), tensor([0.9131], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8972], grad_fn=<SigmoidBackward>), tensor([0.0483], grad_fn=<SigmoidBackward>), tensor([4.6140e-16], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.7924], grad_fn=<SigmoidBackward>), tensor([0.0621], grad_fn=<SigmoidBackward>), tensor([0.9997], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 11, loss -1484.215576171875
# [tensor([0.2177], grad_fn=<SigmoidBackward>), tensor([0.1069], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9369], grad_fn=<SigmoidBackward>), tensor([0.9082], grad_fn=<SigmoidBackward>), tensor([0.9949], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8777], grad_fn=<SigmoidBackward>), tensor([0.5917], grad_fn=<SigmoidBackward>), tensor([0.9982], grad_fn=<SigmoidBackward>), tensor([0.0097], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.9028], grad_fn=<SigmoidBackward>), tensor([0.2188], grad_fn=<SigmoidBackward>), tensor([0.6663], grad_fn=<SigmoidBackward>), tensor([0.0040], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2694], grad_fn=<SigmoidBackward>), tensor([0.3968], grad_fn=<SigmoidBackward>), tensor([0.9970], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7656], grad_fn=<SigmoidBackward>), tensor([0.3240], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9625], grad_fn=<SigmoidBackward>), tensor([0.9930], grad_fn=<SigmoidBackward>), tensor([0.0012], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9957], grad_fn=<SigmoidBackward>), tensor([0.9768], grad_fn=<SigmoidBackward>), tensor([0.0001], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9342], grad_fn=<SigmoidBackward>), tensor([0.0187], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([6.5938e-16], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4290], grad_fn=<SigmoidBackward>), tensor([0.0617], grad_fn=<SigmoidBackward>), tensor([0.5617], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.2064], grad_fn=<SigmoidBackward>), tensor([0.9994], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3859], grad_fn=<SigmoidBackward>), tensor([0.0069], grad_fn=<SigmoidBackward>), tensor([0.9270], grad_fn=<SigmoidBackward>), tensor([0.0210], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8462], grad_fn=<SigmoidBackward>), tensor([0.0045], grad_fn=<SigmoidBackward>), tensor([0.0009], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9544], grad_fn=<SigmoidBackward>), tensor([0.0211], grad_fn=<SigmoidBackward>), tensor([0.4325], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9657], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2688], grad_fn=<SigmoidBackward>), tensor([0.3115], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8980], grad_fn=<SigmoidBackward>), tensor([0.9197], grad_fn=<SigmoidBackward>), tensor([0.1200], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.5153], grad_fn=<SigmoidBackward>), tensor([0.9309], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9427], grad_fn=<SigmoidBackward>), tensor([0.0495], grad_fn=<SigmoidBackward>), tensor([3.5321e-16], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8565], grad_fn=<SigmoidBackward>), tensor([0.0485], grad_fn=<SigmoidBackward>), tensor([0.9998], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 12, loss -1486.38623046875
# [tensor([0.1220], grad_fn=<SigmoidBackward>), tensor([0.0924], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9054], grad_fn=<SigmoidBackward>), tensor([0.9333], grad_fn=<SigmoidBackward>), tensor([0.9932], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8538], grad_fn=<SigmoidBackward>), tensor([0.6414], grad_fn=<SigmoidBackward>), tensor([0.9986], grad_fn=<SigmoidBackward>), tensor([0.0121], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8700], grad_fn=<SigmoidBackward>), tensor([0.2783], grad_fn=<SigmoidBackward>), tensor([0.7282], grad_fn=<SigmoidBackward>), tensor([0.0051], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2134], grad_fn=<SigmoidBackward>), tensor([0.3524], grad_fn=<SigmoidBackward>), tensor([0.9973], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6291], grad_fn=<SigmoidBackward>), tensor([0.2943], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8809], grad_fn=<SigmoidBackward>), tensor([0.9978], grad_fn=<SigmoidBackward>), tensor([0.0004], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9812], grad_fn=<SigmoidBackward>), tensor([0.9940], grad_fn=<SigmoidBackward>), tensor([3.8395e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.8678], grad_fn=<SigmoidBackward>), tensor([0.0311], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([8.9066e-16], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.3588], grad_fn=<SigmoidBackward>), tensor([0.0757], grad_fn=<SigmoidBackward>), tensor([0.5574], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1406], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.2761], grad_fn=<SigmoidBackward>), tensor([0.0100], grad_fn=<SigmoidBackward>), tensor([0.9606], grad_fn=<SigmoidBackward>), tensor([0.0279], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.7525], grad_fn=<SigmoidBackward>), tensor([0.0048], grad_fn=<SigmoidBackward>), tensor([0.0007], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9200], grad_fn=<SigmoidBackward>), tensor([0.0388], grad_fn=<SigmoidBackward>), tensor([0.6978], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9521], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2245], grad_fn=<SigmoidBackward>), tensor([0.2446], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8760], grad_fn=<SigmoidBackward>), tensor([0.9361], grad_fn=<SigmoidBackward>), tensor([0.0995], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4535], grad_fn=<SigmoidBackward>), tensor([0.8844], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8965], grad_fn=<SigmoidBackward>), tensor([0.0466], grad_fn=<SigmoidBackward>), tensor([1.8455e-16], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.7896], grad_fn=<SigmoidBackward>), tensor([0.0582], grad_fn=<SigmoidBackward>), tensor([0.9996], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 13, loss -1482.9398193359375
# [tensor([0.1976], grad_fn=<SigmoidBackward>), tensor([0.1113], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9331], grad_fn=<SigmoidBackward>), tensor([0.9076], grad_fn=<SigmoidBackward>), tensor([0.9949], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8752], grad_fn=<SigmoidBackward>), tensor([0.5989], grad_fn=<SigmoidBackward>), tensor([0.9984], grad_fn=<SigmoidBackward>), tensor([0.0092], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8992], grad_fn=<SigmoidBackward>), tensor([0.2309], grad_fn=<SigmoidBackward>), tensor([0.6877], grad_fn=<SigmoidBackward>), tensor([0.0036], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2565], grad_fn=<SigmoidBackward>), tensor([0.3859], grad_fn=<SigmoidBackward>), tensor([0.9969], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.7455], grad_fn=<SigmoidBackward>), tensor([0.2970], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9530], grad_fn=<SigmoidBackward>), tensor([0.9938], grad_fn=<SigmoidBackward>), tensor([0.0010], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9952], grad_fn=<SigmoidBackward>), tensor([0.9807], grad_fn=<SigmoidBackward>), tensor([9.1890e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9293], grad_fn=<SigmoidBackward>), tensor([0.0180], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([8.8725e-16], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4530], grad_fn=<SigmoidBackward>), tensor([0.0585], grad_fn=<SigmoidBackward>), tensor([0.5811], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1959], grad_fn=<SigmoidBackward>), tensor([0.9995], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3663], grad_fn=<SigmoidBackward>), tensor([0.0070], grad_fn=<SigmoidBackward>), tensor([0.9475], grad_fn=<SigmoidBackward>), tensor([0.0183], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8461], grad_fn=<SigmoidBackward>), tensor([0.0049], grad_fn=<SigmoidBackward>), tensor([0.0013], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9520], grad_fn=<SigmoidBackward>), tensor([0.0235], grad_fn=<SigmoidBackward>), tensor([0.5883], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9613], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2601], grad_fn=<SigmoidBackward>), tensor([0.3039], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.8970], grad_fn=<SigmoidBackward>), tensor([0.9233], grad_fn=<SigmoidBackward>), tensor([0.1090], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.5252], grad_fn=<SigmoidBackward>), tensor([0.9176], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9394], grad_fn=<SigmoidBackward>), tensor([0.0475], grad_fn=<SigmoidBackward>), tensor([1.0684e-16], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8513], grad_fn=<SigmoidBackward>), tensor([0.0455], grad_fn=<SigmoidBackward>), tensor([0.9997], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 14, loss -1475.1859130859375
# [tensor([0.1418], grad_fn=<SigmoidBackward>), tensor([0.0850], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9133], grad_fn=<SigmoidBackward>), tensor([0.9242], grad_fn=<SigmoidBackward>), tensor([0.9937], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8625], grad_fn=<SigmoidBackward>), tensor([0.6385], grad_fn=<SigmoidBackward>), tensor([0.9985], grad_fn=<SigmoidBackward>), tensor([0.0096], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8790], grad_fn=<SigmoidBackward>), tensor([0.2792], grad_fn=<SigmoidBackward>), tensor([0.6890], grad_fn=<SigmoidBackward>), tensor([0.0036], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2230], grad_fn=<SigmoidBackward>), tensor([0.3424], grad_fn=<SigmoidBackward>), tensor([0.9968], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6741], grad_fn=<SigmoidBackward>), tensor([0.2666], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9007], grad_fn=<SigmoidBackward>), tensor([0.9975], grad_fn=<SigmoidBackward>), tensor([0.0005], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# ...
# [tensor([0.8856], grad_fn=<SigmoidBackward>), tensor([0.0603], grad_fn=<SigmoidBackward>), tensor([5.5799e-25], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.7707], grad_fn=<SigmoidBackward>), tensor([0.0174], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 94, loss -1432.784423828125
# [tensor([0.1778], grad_fn=<SigmoidBackward>), tensor([0.2746], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9203], grad_fn=<SigmoidBackward>), tensor([0.9108], grad_fn=<SigmoidBackward>), tensor([0.9954], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8592], grad_fn=<SigmoidBackward>), tensor([0.6010], grad_fn=<SigmoidBackward>), tensor([0.9999], grad_fn=<SigmoidBackward>), tensor([0.0036], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8793], grad_fn=<SigmoidBackward>), tensor([0.3108], grad_fn=<SigmoidBackward>), tensor([0.8067], grad_fn=<SigmoidBackward>), tensor([9.9741e-05], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2195], grad_fn=<SigmoidBackward>), tensor([0.4149], grad_fn=<SigmoidBackward>), tensor([0.9980], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6942], grad_fn=<SigmoidBackward>), tensor([0.2755], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9055], grad_fn=<SigmoidBackward>), tensor([0.9876], grad_fn=<SigmoidBackward>), tensor([0.0004], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9943], grad_fn=<SigmoidBackward>), tensor([0.9823], grad_fn=<SigmoidBackward>), tensor([8.3608e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9208], grad_fn=<SigmoidBackward>), tensor([0.0140], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([1.5859e-24], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4675], grad_fn=<SigmoidBackward>), tensor([0.0622], grad_fn=<SigmoidBackward>), tensor([0.7022], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1936], grad_fn=<SigmoidBackward>), tensor([0.9997], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3252], grad_fn=<SigmoidBackward>), tensor([0.0066], grad_fn=<SigmoidBackward>), tensor([0.9664], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8534], grad_fn=<SigmoidBackward>), tensor([0.0014], grad_fn=<SigmoidBackward>), tensor([0.0185], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9489], grad_fn=<SigmoidBackward>), tensor([0.0337], grad_fn=<SigmoidBackward>), tensor([0.7963], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9946], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2312], grad_fn=<SigmoidBackward>), tensor([0.2349], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9216], grad_fn=<SigmoidBackward>), tensor([0.9731], grad_fn=<SigmoidBackward>), tensor([0.0557], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4880], grad_fn=<SigmoidBackward>), tensor([0.9126], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9110], grad_fn=<SigmoidBackward>), tensor([0.0817], grad_fn=<SigmoidBackward>), tensor([4.3243e-25], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.8013], grad_fn=<SigmoidBackward>), tensor([0.0173], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 95, loss -1432.560302734375
# [tensor([0.1329], grad_fn=<SigmoidBackward>), tensor([0.1566], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9059], grad_fn=<SigmoidBackward>), tensor([0.9196], grad_fn=<SigmoidBackward>), tensor([0.9944], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8483], grad_fn=<SigmoidBackward>), tensor([0.6166], grad_fn=<SigmoidBackward>), tensor([0.9999], grad_fn=<SigmoidBackward>), tensor([0.0043], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8652], grad_fn=<SigmoidBackward>), tensor([0.3347], grad_fn=<SigmoidBackward>), tensor([0.8150], grad_fn=<SigmoidBackward>), tensor([0.0001], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2046], grad_fn=<SigmoidBackward>), tensor([0.3322], grad_fn=<SigmoidBackward>), tensor([0.9977], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6533], grad_fn=<SigmoidBackward>), tensor([0.1610], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8630], grad_fn=<SigmoidBackward>), tensor([0.9927], grad_fn=<SigmoidBackward>), tensor([0.0002], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9897], grad_fn=<SigmoidBackward>), tensor([0.9887], grad_fn=<SigmoidBackward>), tensor([4.1845e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.8969], grad_fn=<SigmoidBackward>), tensor([0.0164], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([6.1688e-25], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4422], grad_fn=<SigmoidBackward>), tensor([0.0612], grad_fn=<SigmoidBackward>), tensor([0.7286], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1662], grad_fn=<SigmoidBackward>), tensor([0.9997], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.2888], grad_fn=<SigmoidBackward>), tensor([0.0072], grad_fn=<SigmoidBackward>), tensor([0.9664], grad_fn=<SigmoidBackward>), tensor([0.0005], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8164], grad_fn=<SigmoidBackward>), tensor([0.0012], grad_fn=<SigmoidBackward>), tensor([0.0215], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9349], grad_fn=<SigmoidBackward>), tensor([0.0380], grad_fn=<SigmoidBackward>), tensor([0.8290], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9946], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2148], grad_fn=<SigmoidBackward>), tensor([0.1750], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9140], grad_fn=<SigmoidBackward>), tensor([0.9749], grad_fn=<SigmoidBackward>), tensor([0.0542], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4640], grad_fn=<SigmoidBackward>), tensor([0.8623], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8865], grad_fn=<SigmoidBackward>), tensor([0.0575], grad_fn=<SigmoidBackward>), tensor([3.8591e-25], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.7717], grad_fn=<SigmoidBackward>), tensor([0.0176], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 96, loss -1430.9368896484375
# [tensor([0.1611], grad_fn=<SigmoidBackward>), tensor([0.1869], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9156], grad_fn=<SigmoidBackward>), tensor([0.9107], grad_fn=<SigmoidBackward>), tensor([0.9951], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8563], grad_fn=<SigmoidBackward>), tensor([0.6023], grad_fn=<SigmoidBackward>), tensor([0.9999], grad_fn=<SigmoidBackward>), tensor([0.0037], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8758], grad_fn=<SigmoidBackward>), tensor([0.3130], grad_fn=<SigmoidBackward>), tensor([0.7872], grad_fn=<SigmoidBackward>), tensor([9.4069e-05], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2146], grad_fn=<SigmoidBackward>), tensor([0.3445], grad_fn=<SigmoidBackward>), tensor([0.9979], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6982], grad_fn=<SigmoidBackward>), tensor([0.1691], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8990], grad_fn=<SigmoidBackward>), tensor([0.9884], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9939], grad_fn=<SigmoidBackward>), tensor([0.9818], grad_fn=<SigmoidBackward>), tensor([6.5613e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9125], grad_fn=<SigmoidBackward>), tensor([0.0137], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([4.6099e-25], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4651], grad_fn=<SigmoidBackward>), tensor([0.0550], grad_fn=<SigmoidBackward>), tensor([0.7265], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1894], grad_fn=<SigmoidBackward>), tensor([0.9997], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3266], grad_fn=<SigmoidBackward>), tensor([0.0062], grad_fn=<SigmoidBackward>), tensor([0.9431], grad_fn=<SigmoidBackward>), tensor([0.0005], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8468], grad_fn=<SigmoidBackward>), tensor([0.0016], grad_fn=<SigmoidBackward>), tensor([0.0271], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9478], grad_fn=<SigmoidBackward>), tensor([0.0294], grad_fn=<SigmoidBackward>), tensor([0.6737], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9957], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2234], grad_fn=<SigmoidBackward>), tensor([0.1972], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9199], grad_fn=<SigmoidBackward>), tensor([0.9724], grad_fn=<SigmoidBackward>), tensor([0.0607], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4897], grad_fn=<SigmoidBackward>), tensor([0.8959], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9075], grad_fn=<SigmoidBackward>), tensor([0.0720], grad_fn=<SigmoidBackward>), tensor([4.6986e-25], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.7997], grad_fn=<SigmoidBackward>), tensor([0.0167], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 97, loss -1430.738525390625
# [tensor([0.1357], grad_fn=<SigmoidBackward>), tensor([0.2061], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9058], grad_fn=<SigmoidBackward>), tensor([0.9208], grad_fn=<SigmoidBackward>), tensor([0.9956], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8511], grad_fn=<SigmoidBackward>), tensor([0.6178], grad_fn=<SigmoidBackward>), tensor([0.9999], grad_fn=<SigmoidBackward>), tensor([0.0035], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8695], grad_fn=<SigmoidBackward>), tensor([0.3312], grad_fn=<SigmoidBackward>), tensor([0.8264], grad_fn=<SigmoidBackward>), tensor([8.3166e-05], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.1985], grad_fn=<SigmoidBackward>), tensor([0.3513], grad_fn=<SigmoidBackward>), tensor([0.9983], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6620], grad_fn=<SigmoidBackward>), tensor([0.1961], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8820], grad_fn=<SigmoidBackward>), tensor([0.9920], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9919], grad_fn=<SigmoidBackward>), tensor([0.9886], grad_fn=<SigmoidBackward>), tensor([5.2751e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.8940], grad_fn=<SigmoidBackward>), tensor([0.0173], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([6.0574e-25], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4419], grad_fn=<SigmoidBackward>), tensor([0.0615], grad_fn=<SigmoidBackward>), tensor([0.7472], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1763], grad_fn=<SigmoidBackward>), tensor([0.9997], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3131], grad_fn=<SigmoidBackward>), tensor([0.0078], grad_fn=<SigmoidBackward>), tensor([0.9718], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8257], grad_fn=<SigmoidBackward>), tensor([0.0015], grad_fn=<SigmoidBackward>), tensor([0.0184], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9433], grad_fn=<SigmoidBackward>), tensor([0.0396], grad_fn=<SigmoidBackward>), tensor([0.8805], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9912], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2117], grad_fn=<SigmoidBackward>), tensor([0.2044], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9148], grad_fn=<SigmoidBackward>), tensor([0.9746], grad_fn=<SigmoidBackward>), tensor([0.0556], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4770], grad_fn=<SigmoidBackward>), tensor([0.9145], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8972], grad_fn=<SigmoidBackward>), tensor([0.0763], grad_fn=<SigmoidBackward>), tensor([5.9301e-25], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.7771], grad_fn=<SigmoidBackward>), tensor([0.0172], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 98, loss -1428.203857421875
# [tensor([0.1391], grad_fn=<SigmoidBackward>), tensor([0.1822], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9067], grad_fn=<SigmoidBackward>), tensor([0.9191], grad_fn=<SigmoidBackward>), tensor([0.9952], grad_fn=<SigmoidBackward>)] tensor([1., 1., 1.])
# [tensor([0.8508], grad_fn=<SigmoidBackward>), tensor([0.6016], grad_fn=<SigmoidBackward>), tensor([0.9999], grad_fn=<SigmoidBackward>), tensor([0.0037], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8700], grad_fn=<SigmoidBackward>), tensor([0.3127], grad_fn=<SigmoidBackward>), tensor([0.7873], grad_fn=<SigmoidBackward>), tensor([0.0001], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.2006], grad_fn=<SigmoidBackward>), tensor([0.3255], grad_fn=<SigmoidBackward>), tensor([0.9983], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.6570], grad_fn=<SigmoidBackward>), tensor([0.2022], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.8848], grad_fn=<SigmoidBackward>), tensor([0.9894], grad_fn=<SigmoidBackward>), tensor([0.0003], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.9923], grad_fn=<SigmoidBackward>), tensor([0.9843], grad_fn=<SigmoidBackward>), tensor([4.2778e-05], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.8985], grad_fn=<SigmoidBackward>), tensor([0.0151], grad_fn=<SigmoidBackward>), tensor([1.], grad_fn=<SigmoidBackward>), tensor([6.7596e-25], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.4609], grad_fn=<SigmoidBackward>), tensor([0.0578], grad_fn=<SigmoidBackward>), tensor([0.7415], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.1784], grad_fn=<SigmoidBackward>), tensor([0.9997], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.3139], grad_fn=<SigmoidBackward>), tensor([0.0074], grad_fn=<SigmoidBackward>), tensor([0.9525], grad_fn=<SigmoidBackward>), tensor([0.0004], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 0.])
# [tensor([0.8334], grad_fn=<SigmoidBackward>), tensor([0.0010], grad_fn=<SigmoidBackward>), tensor([0.0182], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.9450], grad_fn=<SigmoidBackward>), tensor([0.0353], grad_fn=<SigmoidBackward>), tensor([0.7734], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>), tensor([0.9934], grad_fn=<SigmoidBackward>)] tensor([1., 0., 1., 1., 1.])
# [tensor([0.2164], grad_fn=<SigmoidBackward>), tensor([0.1805], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# [tensor([0.9152], grad_fn=<SigmoidBackward>), tensor([0.9727], grad_fn=<SigmoidBackward>), tensor([0.0520], grad_fn=<SigmoidBackward>)] tensor([1., 1., 0.])
# [tensor([0.4858], grad_fn=<SigmoidBackward>), tensor([0.8990], grad_fn=<SigmoidBackward>)] tensor([0., 1.])
# [tensor([0.9010], grad_fn=<SigmoidBackward>), tensor([0.0635], grad_fn=<SigmoidBackward>), tensor([5.9732e-25], grad_fn=<SigmoidBackward>)] tensor([0., 0., 0.])
# [tensor([0.7863], grad_fn=<SigmoidBackward>), tensor([0.0156], grad_fn=<SigmoidBackward>), tensor([1.0000], grad_fn=<SigmoidBackward>)] tensor([0., 0., 1.])
# epoch 99, loss -1426.821044921875
